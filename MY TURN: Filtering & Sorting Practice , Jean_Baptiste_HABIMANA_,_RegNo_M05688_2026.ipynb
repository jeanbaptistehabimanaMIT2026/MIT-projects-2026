# %% [markdown]
# <a href="https://colab.research.google.com/github/jeanbaptistehabimanaMIT2026/MIT-projects-2026/blob/main/MY%20TURN%3A%20Filtering%20%26%20Sorting%20Practice%20%2C%20Jean_Baptiste_HABIMANA_%2C_RegNo_M05688_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# UNIVERSITY OF LAY ADVENTISTS OF KIGALI                           NAME: Jean Baptiste HABIMANA                                     REGNO: M05688/2026
#
# MODULE: C11712(DATA MINING FOR BUSINESS INTELLIGENCE)
#
# DATE: 02/07/2026
#
# MY TURN: Filtering & Sorting Practice
